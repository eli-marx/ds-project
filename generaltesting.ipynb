# %%
import pandas as pd
df_zh = pd.read_csv('combined_output.csv')

# %%
df_en = pd.read_csv("imdb_combined_output.csv")

# %%
df_zh.sort_values('title')
# Out:
#          title                                        review_text  stars  \
# 2780   Aquaman  大脑被按在地上摩擦两个多小时，实在是不吐不快。\n\n海底族既然科技那么发达，当人类认为地球...      2
# 2810   Aquaman  陆地和海底，两个来自不同世界的人类结合，生下一个baby，麻麻为了保护丈夫和孩子，回到海底，...      2
# 2811   Aquaman  这片有7.7分也是醉了，拍的人估计也不好意思得吧，看过最讲故事性也是最不讲故事性的电影，女王...      2
# 2812   Aquaman  看完《海王》，对这个肌肉男的印象是什么？高大，糙汉子，然后就是傻。其他性格，还有什么三观方面...      2
# 2813   Aquaman  好尬的片子～剧情薄弱🉐️可怕～DC的想象力真的触底了！🙃几国大战最后靠整体催眠就解决了？！😲...      2
# ...        ...                                                ...    ...
# 512   Zootopia  看完这部电影，我只记得在电影院最后一排睡觉有多舒服。靠在座椅上，戴上3D眼镜，闭上眼睛，没有...      2
# 511   Zootopia  You can be everything.\n活在幻想的快乐里，总比面对残忍的现实要H叫J...      2
# 510   Zootopia  构建一个逼真的卡通世界一直是好莱坞手到擒来的活，显然这次的动物城也不例外。利用先进的现代电影...      2
# 516   Zootopia  豆瓣的评分一直都是最好的参考，也特别喜欢动画片，但这是第一部评分让我觉得莫名其妙的电影，我从...      2
# 492   Zootopia  好多人都好喜欢这部电影？但是我真的一点也喜欢不起来，虽然有些人物还是挺可爱的。\n听说马上要...      1
#
#                                             url
# ...

# %%
av2 = pd.read_csv('Avatarpart3.csv')
